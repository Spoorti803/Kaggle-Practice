# %% [markdown]
# # Pandas Library
# Pandas is the most popular library of python used for data analysis.
# To work with it, first import the library.(you can use alias for simplicity)

# %%
import pandas as pd

# %% [markdown]
# Two main concepts in pandas are:
#
# 1. DataFrame
# 2. Series
#
# We will create our own data using these as follows

# %% [markdown]
# **DataFrame** <br>
# DataFrame is a table. It contains an array of entries. Each entry corresponds to row and coloumn.
# For example: 31 is a entry whose row=0, column = yes

# %%
data = pd.DataFrame({'yes':[31,3],'no':[33,9]})
print(data)
# Out:
#    yes  no
# 0   31  33
# 1    3   9

# %% [markdown]
# As you can see, the table is automatically given index values which starts for 0.
# If you wish to use give specific values to index, do  follows:

# %%
data = pd.DataFrame({'Bob':["I likes it","Bland"],
                     'Alice':["It was awful","I liked it"]},
                     index = ['Product A','Product B'])
print(data)
# Out:
#                   Bob         Alice
# Product A  I likes it  It was awful
# Product B       Bland    I liked it

# %% [markdown]
# **Series**:
# Series is a sequence of data values. If DataFrame is Table, series is a List.

# %%
data = pd.Series([1,2,3,4])
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# Series is just a colum of DataFrame. So, you can assign a row lable using `index` parameter. However, a Series does not have a column name. It only has one name overall.

# %%
data = pd.Series([30,40,50],index=['Subject A','Subject B','Subject c'],name = 'Marks of a Student')
data
# Out:
# Subject A    30
# Subject B    40
# Subject c    50
# Name: Marks of a Student, dtype: int64

# %% [markdown]
# ### Reading data files

# %% [markdown]
# As of now, we have seen how to create our own data. But, most of the time, we won't be creating data by hand. Instead, we will be working with the already existing data.
# Data can be stored in any format.By far the most used is CSV files. <br>
# CSV stands for Comma separeted values.
# When you open a CSV file, you will get to see the data values separated by commas and hence the name CSV. <br>
# To read the data into DataFrame, we use `pd.read_csv()` function

# %%
data = pd.read_csv("/kaggle/input/datasets/spoortibadiger/network-intrusion-dataset/Wednesday-workingHours.pcap_ISCX.csv")

# %% [markdown]
# Before we move further, let us know how to upload the datasets to kaggle and sue them:
# 1. **Add the dataset (if not already done)** <br>
# In your notebook, look at the right-hand sidebar (in the Notebook editor). Click "Add Input" (sometimes shown as a "+" next to "Input"). Search for your dataset by name and click the + to add it. This mounts it — it doesn't copy files into your working code.
# 2. **Find the exact path** <br>
# Once added, Kaggle places datasets under:<br>
# `/kaggle/input/<dataset-folder-name>/`
# 3. To see the exact folder and file names (they don't always match what you expect), run this in a code cell: <br>
# ```
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
# ```
# Now use the path you get after running this code in the `read_csv()`

# %% [markdown]
# We can use the `shape` attribute to check how large the resulting DataFrame is:

# %%
data.shape
# Out:
# (692703, 79)

# %% [markdown]
# The above output tells us that the new DataFrame created have total of 692703 records split across 79 columns.
# <br>
# To examine the content of the dataset, we can use `head()` command which gives us the first 5 rows of the dataset.

# %%
data.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# ...

# %% [markdown]
# If you wish to fetch more than just 5 rows then specify the nymber of rows in the `head()` command.

# %%
data.head(10)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
# 5                389             433                  11
# 6                 88            1088                   9
# 7                 80          579225                 132
# 8              49666               3                   2
# 9              49413               4                   3
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# ...

# %% [markdown]
# If you wish to checkout the data from last, then use `tail()` command. This command gives the last 5 rows of the dataset.

# %%
data.tail()
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 692698                 53           32215                   4
# 692699                 53             324                   2
# 692700              58030              82                   2
# 692701                 53         1048635                   6
# 692702                 53           94939                   4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 692698                        2                          112
# 692699                        2                           84
# 692700                        1                           31
# 692701                        2                          192
# 692702                        2                          188
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 692698                           152                      28
# 692699                           362                      42
# ...

# %%
#to fetch the last 10 rows of the dataset
data.tail(10)
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 692693                 53             158                   2
# 692694              35450              33                   1
# 692695                 53           46982                   2
# 692696                 80        11512230                   5
# 692697              49346             145                   1
# 692698                 53           32215                   4
# 692699                 53             324                   2
# 692700              58030              82                   2
# 692701                 53         1048635                   6
# 692702                 53           94939                   4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 692693                        2                           82
# 692694                        1                            0
# 692695                        2                           58
# ...

# %% [markdown]
# The `pd.read_csv()` has over 30 optional parameters. For example, you can see in this dataset taht the CSV file has a built-in index, which pandas did not pick up automatically. To make pandas use that column for the index (instead of creating a new one from scratch), we can specify an `index_col`.

# %%
data = pd.read_csv("/kaggle/input/datasets/spoortibadiger/network-intrusion-dataset/Wednesday-workingHours.pcap_ISCX.csv",index_col=0)
data.head()
# Out:
#                     Flow Duration   Total Fwd Packets  \
#  Destination Port
# 80                          38308                   1
# 389                           479                  11
# 88                           1095                  10
# 389                         15206                  17
# 88                           1092                   9
#
#                     Total Backward Packets  Total Length of Fwd Packets  \
#  Destination Port
# 80                                       1                            6
# 389                                      5                          172
# 88                                       6                         3150
# 389                                     12                         3452
# 88                                       6                         3150
#
#                     Total Length of Bwd Packets   Fwd Packet Length Max  \
#  Destination Port
# ...

# %% [markdown]
# Now, let us learn how to save a DataFarme as CSV to disk using `to_csv`.
# Let us create a DataFrame called animals and save it as a CSV file to disk under the name `cows_and_goats.csv`.

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
#use the function to_csv() to convert the datafame to csv
animals.to_csv("cows_and_goats.csv")

# %% [markdown]
# ### Indexing, Selecting and assigning
